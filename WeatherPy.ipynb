# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
import json

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 578

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = 'https://api.openweathermap.org/data/2.5/weather?'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&units=metric&appid={weather_api_key}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | isafjordur
# City not found. Skipping...
# Processing Record 2 of Set 1 | ribeira grande
# City not found. Skipping...
# Processing Record 3 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 4 of Set 1 | whitehorse
# City not found. Skipping...
# Processing Record 5 of Set 1 | nova sintra
# City not found. Skipping...
# Processing Record 6 of Set 1 | albany
# City not found. Skipping...
# Processing Record 7 of Set 1 | victoria
# City not found. Skipping...
# Processing Record 8 of Set 1 | tralee
# City not found. Skipping...
# Processing Record 9 of Set 1 | fort bragg
# City not found. Skipping...
# Processing Record 10 of Set 1 | waitangi
# City not found. Skipping...
# Processing Record 11 of Set 1 | port-aux-francais
# City not found. Skipping...
# Processing Record 12 of Set 1 | gizo
# City not found. Skipping...
# Processing Record 13 of Set 1 | kirs
# City not found. Skipping...
# Processing Record 14 of Set 1 | olonkinbyen
# City not found. Skipping...
# Processing Record 15 of Set 1 | georgetown
# City not found. Skipping...
# Processing Record 16 of Set 1 | iqaluit
# City not found. Skipping...
# Processing Record 17 of Set 1 | kingsbridge
# City not found. Skipping...
# Processing Record 18 of Set 1 | mount isa
# City not found. Skipping...
# Processing Record 19 of Set 1 | ciudad lazaro cardenas
# City not found. Skipping...
# Processing Record 20 of Set 1 | gonzalez
# City not found. Skipping...
# Processing Record 21 of Set 1 | yellowknife
# City not found. Skipping...
# Processing Record 22 of Set 1 | carqueiranne
# City not found. Skipping...
# Processing Record 23 of Set 1 | naze
# City not found. Skipping...
# Processing Record 24 of Set 1 | demyansk
# City not found. Skipping...
# Processing Record 25 of Set 1 | puerto natales
# City not found. Skipping...
# Processing Record 26 of Set 1 | salalah
# City not found. Skipping...
# Processing Record 27 of Set 1 | fortuna
# City not found. Skipping...
# Processing Record 28 of Set 1 | hamilton
# City not found. Skipping...
# Processing Record 29 of Set 1 | blackmans bay
# City not found. Skipping...
# Processing Record 30 of Set 1 | grytviken
# City not found. Skipping...
# Processing Record 31 of Set 1 | iskateley
# City not found. Skipping...
# Processing Record 32 of Set 1 | edinburgh of the seven seas
# City not found. Skipping...
# Processing Record 33 of Set 1 | bethel
# City not found. Skipping...
# Processing Record 34 of Set 1 | ganjam
# City not found. Skipping...
# Processing Record 35 of Set 1 | west island
# City not found. Skipping...
# Processing Record 36 of Set 1 | ilulissat
# City not found. Skipping...
# Processing Record 37 of Set 1 | abraham's bay
# City not found. Skipping...
# Processing Record 38 of Set 1 | kayangel
# City not found. Skipping...
# Processing Record 39 of Set 1 | kodiak
# City not found. Skipping...
# Processing Record 40 of Set 1 | shetpe
# City not found. Skipping...
# Processing Record 41 of Set 1 | ola
# City not found. Skipping...
# Processing Record 42 of Set 1 | tofol
# City not found. Skipping...
# Processing Record 43 of Set 1 | port elizabeth
# City not found. Skipping...
# Processing Record 44 of Set 1 | bodo
# City not found. Skipping...
# Processing Record 45 of Set 1 | st. john's
# City not found. Skipping...
# Processing Record 46 of Set 1 | adamstown
# City not found. Skipping...
# Processing Record 47 of Set 1 | nishon tumani
# City not found. Skipping...
# Processing Record 48 of Set 1 | tazovsky
# City not found. Skipping...
# Processing Record 49 of Set 1 | nagqu
# City not found. Skipping...
# Processing Record 50 of Set 1 | naryn
# City not found. Skipping...
# Processing Record 0 of Set 2 | colchani
# City not found. Skipping...
# Processing Record 1 of Set 2 | rongelap
# City not found. Skipping...
# Processing Record 2 of Set 2 | papatowai
# City not found. Skipping...
# Processing Record 3 of Set 2 | san luis de la loma
# City not found. Skipping...
# Processing Record 4 of Set 2 | tura
# City not found. Skipping...
# Processing Record 5 of Set 2 | tanrake village
# City not found. Skipping...
# Processing Record 6 of Set 2 | margaret river
# City not found. Skipping...
# Processing Record 7 of Set 2 | buka
# City not found. Skipping...
# Processing Record 8 of Set 2 | velimese
# City not found. Skipping...
# Processing Record 9 of Set 2 | college
# City not found. Skipping...
# Processing Record 10 of Set 2 | hithadhoo
# City not found. Skipping...
# Processing Record 11 of Set 2 | santa cruz
# City not found. Skipping...
# Processing Record 12 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 13 of Set 2 | al jawf
# City not found. Skipping...
# Processing Record 14 of Set 2 | alice springs
# City not found. Skipping...
# Processing Record 15 of Set 2 | vila nova de foz coa
# City not found. Skipping...
# Processing Record 16 of Set 2 | petropavlovsk-kamchatsky
# City not found. Skipping...
# Processing Record 17 of Set 2 | aykhal
# City not found. Skipping...
# Processing Record 18 of Set 2 | port hedland
# City not found. Skipping...
# Processing Record 19 of Set 2 | languyan
# City not found. Skipping...
# Processing Record 20 of Set 2 | rio gallegos
# City not found. Skipping...
# Processing Record 21 of Set 2 | new norfolk
# City not found. Skipping...
# Processing Record 22 of Set 2 | holualoa
# City not found. Skipping...
# Processing Record 23 of Set 2 | aasiaat
# City not found. Skipping...
# Processing Record 24 of Set 2 | uturoa
# City not found. Skipping...
# Processing Record 25 of Set 2 | port blair
# City not found. Skipping...
# Processing Record 26 of Set 2 | longyearbyen
# City not found. Skipping...
# Processing Record 27 of Set 2 | sinop
# City not found. Skipping...
# Processing Record 28 of Set 2 | walvis bay
# City not found. Skipping...
# Processing Record 29 of Set 2 | fuvahmulah
# City not found. Skipping...
# Processing Record 30 of Set 2 | invercargill
# City not found. Skipping...
# Processing Record 31 of Set 2 | badger
# City not found. Skipping...
# Processing Record 32 of Set 2 | mathba
# City not found. Skipping...
# Processing Record 33 of Set 2 | coquimbo
# City not found. Skipping...
# Processing Record 34 of Set 2 | stanley
# City not found. Skipping...
# Processing Record 35 of Set 2 | east london
# City not found. Skipping...
# Processing Record 36 of Set 2 | ushuaia
# City not found. Skipping...
# Processing Record 37 of Set 2 | punta arenas
# City not found. Skipping...
# Processing Record 38 of Set 2 | castillos
# City not found. Skipping...
# Processing Record 39 of Set 2 | sisimiut
# City not found. Skipping...
# Processing Record 40 of Set 2 | terme
# City not found. Skipping...
# Processing Record 41 of Set 2 | isla mujeres
# City not found. Skipping...
# Processing Record 42 of Set 2 | sturgeon bay
# City not found. Skipping...
# Processing Record 43 of Set 2 | great falls
# City not found. Skipping...
# Processing Record 44 of Set 2 | puerto ayora
# City not found. Skipping...
# Processing Record 45 of Set 2 | cambria
# City not found. Skipping...
# Processing Record 46 of Set 2 | anadyr
# City not found. Skipping...
# Processing Record 47 of Set 2 | fontanelas
# City not found. Skipping...
# Processing Record 48 of Set 2 | nuevo casas grandes
# City not found. Skipping...
# Processing Record 49 of Set 2 | solnechnyy
# City not found. Skipping...
# Processing Record 0 of Set 3 | lamu
# City not found. Skipping...
# Processing Record 1 of Set 3 | mossel bay
# City not found. Skipping...
# Processing Record 2 of Set 3 | ataq
# City not found. Skipping...
# Processing Record 3 of Set 3 | guerrero negro
# City not found. Skipping...
# Processing Record 4 of Set 3 | acapulco de juarez
# City not found. Skipping...
# Processing Record 5 of Set 3 | enewetak
# City not found. Skipping...
# Processing Record 6 of Set 3 | kapuskasing
# City not found. Skipping...
# Processing Record 7 of Set 3 | lihue
# City not found. Skipping...
# Processing Record 8 of Set 3 | sebastopol
# City not found. Skipping...
# Processing Record 9 of Set 3 | oroqen zizhiqi
# City not found. Skipping...
# Processing Record 10 of Set 3 | polyarnyy
# City not found. Skipping...
# Processing Record 11 of Set 3 | timaru
# City not found. Skipping...
# Processing Record 12 of Set 3 | atafu village
# City not found. Skipping...
# Processing Record 13 of Set 3 | bredasdorp
# City not found. Skipping...
# Processing Record 14 of Set 3 | qaqortoq
# City not found. Skipping...
# Processing Record 15 of Set 3 | thompson
# City not found. Skipping...
# Processing Record 16 of Set 3 | markovo
# City not found. Skipping...
# Processing Record 17 of Set 3 | klyuchi
# City not found. Skipping...
# Processing Record 18 of Set 3 | avarua
# City not found. Skipping...
# Processing Record 19 of Set 3 | egilsstadir
# City not found. Skipping...
# Processing Record 20 of Set 3 | rio preto da eva
# City not found. Skipping...
# Processing Record 21 of Set 3 | flying fish cove
# City not found. Skipping...
# Processing Record 22 of Set 3 | vorgashor
# City not found. Skipping...
# Processing Record 23 of Set 3 | beaufort west
# City not found. Skipping...
# Processing Record 24 of Set 3 | broken hill
# City not found. Skipping...
# Processing Record 25 of Set 3 | nevel'sk
# City not found. Skipping...
# Processing Record 26 of Set 3 | inhambane
# City not found. Skipping...
# Processing Record 27 of Set 3 | kamuthi
# City not found. Skipping...
# Processing Record 28 of Set 3 | hermanus
# City not found. Skipping...
# Processing Record 29 of Set 3 | mahibadhoo
# City not found. Skipping...
# Processing Record 30 of Set 3 | illizi
# City not found. Skipping...
# Processing Record 31 of Set 3 | port lincoln
# City not found. Skipping...
# Processing Record 32 of Set 3 | saipan
# City not found. Skipping...
# Processing Record 33 of Set 3 | fisterra
# City not found. Skipping...
# Processing Record 34 of Set 3 | yulinshi
# City not found. Skipping...
# Processing Record 35 of Set 3 | vilyuchinsk
# City not found. Skipping...
# Processing Record 36 of Set 3 | marquette
# City not found. Skipping...
# Processing Record 37 of Set 3 | puertollano
# City not found. Skipping...
# Processing Record 38 of Set 3 | happy valley-goose bay
# City not found. Skipping...
# Processing Record 39 of Set 3 | padre paraiso
# City not found. Skipping...
# Processing Record 40 of Set 3 | fomboni
# City not found. Skipping...
# Processing Record 41 of Set 3 | amursk
# City not found. Skipping...
# Processing Record 42 of Set 3 | mazatlan
# City not found. Skipping...
# Processing Record 43 of Set 3 | aripuana
# City not found. Skipping...
# Processing Record 44 of Set 3 | tommot
# City not found. Skipping...
# Processing Record 45 of Set 3 | dudinka
# City not found. Skipping...
# Processing Record 46 of Set 3 | nema
# City not found. Skipping...
# Processing Record 47 of Set 3 | willemstad
# City not found. Skipping...
# Processing Record 48 of Set 3 | mount pearl
# City not found. Skipping...
# Processing Record 49 of Set 3 | sotouboua
# City not found. Skipping...
# Processing Record 0 of Set 4 | tsiombe
# City not found. Skipping...
# Processing Record 1 of Set 4 | severo-yeniseyskiy
# City not found. Skipping...
# Processing Record 2 of Set 4 | acarau
# City not found. Skipping...
# Processing Record 3 of Set 4 | freeport
# City not found. Skipping...
# Processing Record 4 of Set 4 | mezgor'e
# City not found. Skipping...
# Processing Record 5 of Set 4 | berdigestyakh
# City not found. Skipping...
# Processing Record 6 of Set 4 | itaituba
# City not found. Skipping...
# Processing Record 7 of Set 4 | tarazona
# City not found. Skipping...
# Processing Record 8 of Set 4 | morehead city
# City not found. Skipping...
# Processing Record 9 of Set 4 | panshan
# City not found. Skipping...
# Processing Record 10 of Set 4 | west bay
# City not found. Skipping...
# Processing Record 11 of Set 4 | braniewo
# City not found. Skipping...
# Processing Record 12 of Set 4 | camayenne
# City not found. Skipping...
# Processing Record 13 of Set 4 | susuman
# City not found. Skipping...
# Processing Record 14 of Set 4 | bilibino
# City not found. Skipping...
# Processing Record 15 of Set 4 | corner brook
# City not found. Skipping...
# Processing Record 16 of Set 4 | island harbour
# City not found. Skipping...
# Processing Record 17 of Set 4 | ancud
# City not found. Skipping...
# Processing Record 18 of Set 4 | weno
# City not found. Skipping...
# Processing Record 19 of Set 4 | coihueco
# City not found. Skipping...
# Processing Record 20 of Set 4 | gabu
# City not found. Skipping...
# Processing Record 21 of Set 4 | new plymouth
# City not found. Skipping...
# Processing Record 22 of Set 4 | mochudi
# City not found. Skipping...
# Processing Record 23 of Set 4 | talnakh
# City not found. Skipping...
# Processing Record 24 of Set 4 | soio
# City not found. Skipping...
# Processing Record 25 of Set 4 | hasaki
# City not found. Skipping...
# Processing Record 26 of Set 4 | fale old settlement
# City not found. Skipping...
# Processing Record 27 of Set 4 | cadale
# City not found. Skipping...
# Processing Record 28 of Set 4 | el tambo
# City not found. Skipping...
# Processing Record 29 of Set 4 | haiku-pauwela
# City not found. Skipping...
# Processing Record 30 of Set 4 | jamestown
# City not found. Skipping...
# Processing Record 31 of Set 4 | pisco
# City not found. Skipping...
# Processing Record 32 of Set 4 | abadan
# City not found. Skipping...
# Processing Record 33 of Set 4 | emmett
# City not found. Skipping...
# Processing Record 34 of Set 4 | dergachi
# City not found. Skipping...
# Processing Record 35 of Set 4 | palmer
# City not found. Skipping...
# Processing Record 36 of Set 4 | kuressaare
# City not found. Skipping...
# Processing Record 37 of Set 4 | pasil
# City not found. Skipping...
# Processing Record 38 of Set 4 | roma
# City not found. Skipping...
# Processing Record 39 of Set 4 | awjilah
# City not found. Skipping...
# Processing Record 40 of Set 4 | minas de marcona
# City not found. Skipping...
# Processing Record 41 of Set 4 | batala
# City not found. Skipping...
# Processing Record 42 of Set 4 | north bend
# City not found. Skipping...
# Processing Record 43 of Set 4 | hovd
# City not found. Skipping...
# Processing Record 44 of Set 4 | carnarvon
# City not found. Skipping...
# Processing Record 45 of Set 4 | constantia
# City not found. Skipping...
# Processing Record 46 of Set 4 | kotabumi
# City not found. Skipping...
# Processing Record 47 of Set 4 | san antonio de pale
# City not found. Skipping...
# Processing Record 48 of Set 4 | wailua homesteads
# City not found. Skipping...
# Processing Record 49 of Set 4 | tazacorte
# City not found. Skipping...
# Processing Record 0 of Set 5 | mamou
# City not found. Skipping...
# Processing Record 1 of Set 5 | mar del plata
# City not found. Skipping...
# Processing Record 2 of Set 5 | dunedin
# Processing Record 3 of Set 5 | bokani
# Processing Record 4 of Set 5 | witu
# Processing Record 5 of Set 5 | lauchringen
# Processing Record 6 of Set 5 | sur

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
# Show Record Count
city_data_df.count()

# %%
# Display sample data
city_data_df.head()

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature(C)')
plt.title('City Latitude vs.Temperature(2022-10-18)')
plt.grid()


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'],city_data_df['Humidity'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.title('City Latitude vs.Humidity(2022-10-18)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'],city_data_df['Cloudiness'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.title('City Latitude vs.Cloudiness(2022-10-18)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'],city_data_df['Wind Speed'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')
plt.title('City Latitude vs.Wind Speed(2022-10-18)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_reg(x_axis, y_axis,eq_loc):  
    correlation = st.pearsonr(x_axis,y_axis)
    p_slope, p_int, p_r, p_p, p_std_err = st.linregress(x_axis, y_axis)
    p_fit = p_slope * x_axis + p_int
    eq= f"y ={p_slope: .2f}x +{ p_int: .2f}"
       
    #Plot the line
    plt.scatter(x_axis, y_axis ,marker="o")
    plt.plot(x_axis,p_fit,"--", color='red')
    plt.annotate(eq, eq_loc, fontsize=12, color='red')
    print(f"The r-value between {x_axis.name} and {y_axis.name} is {round(correlation[0],2)}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>=0]

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<0]


# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'],(10, -10))
plt.xlabel('Latitude')
plt.ylabel('Temperature(C)')

# %%
# Linear regression on Southern Hemisphere
linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'],(-30, 5))
plt.xlabel('Latitude')
plt.ylabel('Temperature(C)')

# %% [markdown]
# **Discussion about the linear relationship:** In the Northern Hemisphere the cities latitude and temperature has a strong negative correlation which proves that the higher the latitude of the city is, the lower the temperature will be. On the other hand in the Southere Hemisphere the cities latitude and temperature have a fairly positive correlation which shows that the higher the latitude of the city, the higher the temperature will be.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Humidity'],(55, 10))
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')

# %%
# Southern Hemisphere
linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Humidity'],(-50, 25))
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')

# %% [markdown]
# **Discussion about the linear relationship:** In the Northern Hemisphere the cities latitude and humidity have a weak positive correlation which proves that with the increase of the latitude of the city, the humidity is also likely to increase. Similar to the Northeres Hemisphere, for the Southeren Hemisphere the cities latitude and temperature have a weak positive correlation as well which also shows that with the increase in latitude of the city, the humidity will also be minimal.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'],(50, 50))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')

# %%
# Southern Hemisphere
linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'],(-50, 65))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'],(10, 12))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')

# %%
# Southern Hemisphere
linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'],(-50, 9))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
